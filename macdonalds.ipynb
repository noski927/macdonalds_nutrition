# %% [markdown]
# <a href="https://colab.research.google.com/github/noski927/macdonalds_nutrition/blob/first/macdonalds.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install beautifulsoup4

# %%
import pandas as pd
from bs4 import BeautifulSoup
import numpy as np
import requests
import matplotlib.pyplot as plt

# %%
r=requests.get('https://mrestaurans.ru/menu')
print(r.content)
# Out:
# b'<!DOCTYPE html>\n<html lang="ru">\n\t<head>\n\t\t<meta charset="UTF-8">\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n<meta name="viewport" content="width=device-width, initial-scale=1">\n<title>\xd0\x9c\xd0\xb5\xd0\xbd\xd1\x8e \xd0\x9c\xd0\xb0\xd0\xba\xd0\xb4\xd0\xbe\xd0\xbd\xd0\xb0\xd0\xbb\xd1\x8c\xd0\xb4\xd1\x81 2021: \xd1\x86\xd0\xb5\xd0\xbd\xd1\x8b, \xd1\x84\xd0\xbe\xd1\x82\xd0\xbe, \xd1\x81\xd0\xbe\xd1\x81\xd1\x82\xd0\xb0\xd0\xb2, \xd0\xba\xd0\xb0\xd0\xbb\xd0\xbe\xd1\x80\xd0\xb8\xd0\xb8</title>\n<meta name="description" content=\'\xd0\x92\xd1\x81\xd0\xb5 \xd0\x9c\xd0\xb5\xd0\xbd\xd1\x8e \xd0\xb2 \xd0\x9c\xd0\xb0\xd0\xba\xd0\xb4\xd0\xbe\xd0\xbd\xd0\xb0\xd0\xbb\xd1\x8c\xd0\xb4\xd1\x81 \xd0\xbd\xd0\xb0 2021 \xd0\xb3\xd0\xbe\xd0\xb4. \xd0\xa6\xd0\xb5\xd0\xbd\xd1\x8b, \xd1\x84\xd0\xbe\xd1\x82\xd0\xbe, \xd1\x81\xd0\xbe\xd1\x81\xd1\x82\xd0\xb0\xd0\xb2, \xd0\xba\xd0\xb0\xd0\xbb\xd0\xbe\xd1\x80\xd0\xb8\xd0\xb8.\'>\n<link rel="shortcut icon" href="/favicon.ico" type="image/x-
# ...

# %%
soup=BeautifulSoup(r.content,'html.parser')

# %%
listing=soup.find_all('div','eda-wrap')[:10]
listing[0]
# Out:
# <div class="eda-wrap">
# <div class="eda-tit margin-b"><a href="menu/grik-mak">Грик Мак	™</a></div>
# <a href="menu/grik-mak"><img alt="Грик Мак	™" src="/assets/components/phpthumbof/cache/grik-mak2.4d0b89381ccf466a6b73b35d2ce5192a.jpg" title="Грик Мак	™"/></a>
# <div class="cena">Цена: <span>160</span> руб.</div>
# </div>

# %%
listing[0].find_all('a')[0].get('href')
# Out:
# 'menu/grik-mak'
